# %% [markdown]
# #### Importing necessary libraries

# %%
import pandas as pd
import numpy as np

import pymysql
from sqlalchemy import create_engine

from getpass import getpass  # To get the password without showing the input

# %% [markdown]
# #### Assigning mySQL password

# %%
password = getpass()
# Out:
# ········

# %% [markdown]
# #### Conneting mySQL to Jupyter

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
engine = create_engine(connection_string)

# %% [markdown]
# #### 1. How many distinct (different) actors' last names are there?

# %%
data1 = pd.read_sql_query('''SELECT COUNT(DISTINCT last_name)  as "Unique_actor's_last _name"
FROM sakila.actor;''', engine)
data1.head()
# Out:
#    Unique_actor's_last _name
# 0                        121

# %% [markdown]
# #### 2. Add an additional column day_type with values 'weekend' and 'workday' depending on the rental day of the week.

# %%
data2 = pd.read_sql_query('''SELECT *, 
CASE
WHEN  DAYOFWEEK(CONVERT(rental_date,DATE)) BETWEEN 1 AND 5 THEN 'workday'
ELSE 'weekend' 
END AS 'day_type'
FROM sakila.rental;'''
, engine)
data2.head()
# Out:
#    rental_id         rental_date  inventory_id  customer_id  \
# 0          1 2005-05-24 22:53:30           367          130
# 1          2 2005-05-24 22:54:33          1525          459
# 2          3 2005-05-24 23:03:39          1711          408
# 3          4 2005-05-24 23:04:41          2452          333
# 4          5 2005-05-24 23:05:21          2079          222
#
#           return_date  staff_id         last_update day_type
# 0 2005-05-26 22:04:30         1 2006-02-15 21:30:53  workday
# 1 2005-05-28 19:40:33         1 2006-02-15 21:30:53  workday
# 2 2005-06-01 22:12:39         1 2006-02-15 21:30:53  workday
# 3 2005-06-03 01:43:41         2 2006-02-15 21:30:53  workday
# 4 2005-06-02 04:33:21         1 2006-02-15 21:30:53  workday

# %% [markdown]
# #### 3. Get all films with ARMAGEDDON in the title.

# %%
data3 = engine.execute( ''' SELECT film_id, title
FROM sakila.film
WHERE title LIKE '%%ARMAGEDDON%%'; ''')

rows = []
for row in data3:
    rows.append(row)
    print(row)
# Out:
# (39, 'ARMAGEDDON LOST')
# (507, 'LADYBUGS ARMAGEDDON')
# (571, 'METAL ARMAGEDDON')
# (598, 'MOSQUITO ARMAGEDDON')
# (838, 'STAGECOACH ARMAGEDDON')
# (844, 'STEERS ARMAGEDDON')

# %%
data3=pd.DataFrame(rows)
data3.head()
# Out:
#    film_id                  title
# 0       39        ARMAGEDDON LOST
# 1      507    LADYBUGS ARMAGEDDON
# 2      571       METAL ARMAGEDDON
# 3      598    MOSQUITO ARMAGEDDON
# 4      838  STAGECOACH ARMAGEDDON

# %% [markdown]
# #### 4. Get 10 the longest films.

# %%
data4 = pd.read_sql_query('''SELECT title, length
FROM sakila.film
order by  length Desc
limit 10;''', engine)
data4.head()
# Out:
#             title  length
# 0  DARN FORRESTER     185
# 1    POND SEATTLE     185
# 2   CHICAGO NORTH     185
# 3   MUSCLE BRIGHT     185
# 4    WORST BANGER     185

# %% [markdown]
# #### 5. How many films include Behind the Scenes content

# %%
# better to use explicit names, otherwise we get duplicate column names

data5 = engine.execute( '''SELECT * 
FROM sakila.film
WHERE special_features LIKE '%%Behind the Scenes%%';''')

rows = []
for row in data5:
    rows.append(row)
    print(row)
# Out:
# (1, 'ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 86, Decimal('20.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (4, 'AFFAIR PREJUDICE', 'A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank', 2006, 1, None, 5, Decimal('2.99'), 117, Decimal('26.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (11, 'ALAMO VIDEOTAPE', 'A Boring Epistle of a Butler And a Cat who must Fight a Pastry Chef in A MySQL Convention', 2006, 1, None, 6, Decimal('0.99'), 126, Decimal('16.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (13, 'ALI FOREVER', 'A Action-Packed Drama of a Dentist And a Crocodile who must Battle a Feminist in The Canadian Rockies', 2006, 1, None, 4, Decimal('4.99'), 150, Decimal('21.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (14, 'ALICE FANTASIA', 'A Emotional Drama of a A Shark And a Database Administrator who must Vanquish a Pioneer in Soviet Georgia', 2006, 1, None, 6, Decimal('0.99'), 94, Decimal('23.99'), 'NC-17', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (15, 'ALIEN CENTER', 'A Brilliant Drama of a Cat And a Mad Scientist who must Battle a Feminist in A MySQL Convention', 2006, 1, None, 5, Decimal('2.99'), 46, Decimal('10.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (17, 'ALONE TRIP', 'A Fast-Paced Character Study of a Composer And a Dog who must Outgun a Boat in An Abandoned Fun House', 2006, 1, None, 3, Decimal('0.99'), 82, Decimal('14.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (18, 'ALTER VICTORY', 'A Thoughtful Drama of a Composer And a Feminist who must Meet a Secret Agent in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 57, Decimal('27.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (19, 'AMADEUS HOLY', 'A Emotional Display of a Pioneer And a Technical Writer who must Battle a Man in A Baloon', 2006, 1, None, 6, Decimal('0.99'), 113, Decimal('20.99'), 'PG', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (20, 'AMELIE HELLFIGHTERS', 'A Boring Drama of a Woman And a Squirrel who must Conquer a Student in A Baloon', 2006, 1, None, 4, Decimal('4.99'), 79, Decimal('23.99'), 'R', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (21, 'AMERICAN CIRCUS', 'A Insightful Drama of a Girl And a Astronaut who must Face a Database Administrator in A Shark Tank', 2006, 1, None, 3, Decimal('4.99'), 129, Decimal('17.99'), 'R', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (22, 'AMISTAD MIDSUMMER', 'A Emotional Character Study of a Dentist And a Crocodile who must Meet a Sumo Wrestler in California', 2006, 1, None, 6, Decimal('2.99'), 85, Decimal('10.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (24, 'ANALYZE HOOSIERS', 'A Thoughtful Display of a Explorer And a Pastry Chef who must Overcome a Feminist in The Sahara Desert', 2006, 1, None, 6, Decimal('2.99'), 181, Decimal('19.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (27, 'ANONYMOUS HUMAN', 'A Amazing Reflection of a Database Administrator And a Astronaut who must Outrace a Database Administrator in A Shark Tank', 2006, 1, None, 7, Decimal('0.99'), 179, Decimal('12.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (28, 'ANTHEM LUKE', 'A Touching Panorama of a Waitress And a Woman who must Outrace a Dog in An Abandoned Amusement Park', 2006, 1, None, 5, Decimal('4.99'), 91, Decimal('16.99'), 'PG-13', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (30, 'ANYTHING SAVANNAH', 'A Epic Story of a Pastry Chef And a Woman who must Chase a Feminist in An Abandoned Fun House', 2006, 1, None, 4, Decimal('2.99'), 82, Decimal('27.99'), 'R', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (31, 'APACHE DIVINE', 'A Awe-Inspiring Reflection of a Pastry Chef And a Teacher who must Overcome a Sumo Wrestler in A U-Boat', 2006, 1, None, 5, Decimal('4.99'), 92, Decimal('16.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (33, 'APOLLO TEEN', 'A Action-Packed Reflection of a Crocodile And a Explorer who must Find a Sumo Wrestler in An Abandoned Mine Shaft', 2006, 1, None, 5, Decimal('2.99'), 153, Decimal('15.99'), 'PG-13', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (35, 'ARACHNOPHOBIA ROLLERCOASTER', 'A Action-Packed Reflection of a Pastry Chef And a Composer who must Discover a Mad Scientist in The First Manned Space Station', 2006, 1, None, 4, Decimal('2.99'), 147, Decimal('24.99'), 'PG-13', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (38, 'ARK RIDGEMONT', 'A Beautiful Yarn of a Pioneer And a Monkey who must Pursue a Explorer in The Sahara Desert', 2006, 1, None, 6, Decimal('0.99'), 68, Decimal('25.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (41, 'ARSENIC INDEPENDENCE', 'A Fanciful Documentary of a Mad Cow And a Womanizer who must Find a Dentist in Berlin', 2006, 1, None, 4, Decimal('0.99'), 137, Decimal('17.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (42, 'ARTIST COLDBLOODED', 'A Stunning Reflection of a Robot And a Moose who must Challenge a Woman in California', 2006, 1, None, 5, Decimal('2.99'), 170, Decimal('10.99'), 'NC-17', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (43, 'ATLANTIS CAUSE', 'A Thrilling Yarn of a Feminist And a Hunter who must Fight a Technical Writer in A Shark Tank', 2006, 1, None, 6, Decimal('2.99'), 170, Decimal('15.99'), 'G', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (44, 'ATTACKS HATE', 'A Fast-Paced Panorama of a Technical Writer And a Mad Scientist who must Find a Feminist in An Abandoned Mine Shaft', 2006, 1, None, 5, Decimal('4.99'), 113, Decimal('21.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (45, 'ATTRACTION NEWTON', 'A Astounding Panorama of a Composer And a Frisbee who must Reach a Husband in Ancient Japan', 2006, 1, None, 5, Decimal('4.99'), 83, Decimal('14.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (46, 'AUTUMN CROW', 'A Beautiful Tale of a Dentist And a Mad Cow who must Battle a Moose in The Sahara Desert', 2006, 1, None, 3, Decimal('4.99'), 108, Decimal('13.99'), 'G', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (48, 'BACKLASH UNDEFEATED', 'A Stunning Character Study of a Mad Scientist And a Mad Cow who must Kill a Car in A Monastery', 2006, 1, None, 3, Decimal('4.99'), 118, Decimal('24.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (49, 'BADMAN DAWN', 'A Emotional Panorama of a Pioneer And a Composer who must Escape a Mad Scientist in A Jet Boat', 2006, 1, None, 6, Decimal('2.99'), 162, Decimal('22.99'), 'R', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (50, 'BAKED CLEOPATRA', 'A Stunning Drama of a Forensic Psychologist And a Husband who must Overcome a Waitress in A Monastery', 2006, 1, None, 3, Decimal('2.99'), 182, Decimal('20.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (53, 'BANG KWAI', 'A Epic Drama of a Madman And a Cat who must Face a A Shark in An Abandoned Amusement Park', 2006, 1, None, 5, Decimal('2.99'), 87, Decimal('25.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (55, 'BARBARELLA STREETCAR', 'A Awe-Inspiring Story of a Feminist And a Cat who must Conquer a Dog in A Monastery', 2006, 1, None, 6, Decimal('2.99'), 65, Decimal('27.99'), 'G', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (58, 'BEACH HEARTBREAKERS', 'A Fateful Display of a Womanizer And a Mad Scientist who must Outgun a A Shark in Soviet Georgia', 2006, 1, None, 6, Decimal('2.99'), 122, Decimal('16.99'), 'G', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (60, 'BEAST HUNCHBACK', 'A Awe-Inspiring Epistle of a Student And a Squirrel who must Defeat a Boy in Ancient China', 2006, 1, None, 3, Decimal('4.99'), 89, Decimal('22.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (63, 'BEDAZZLED MARRIED', 'A Astounding Character Study of a Madman And a Robot who must Meet a Mad Scientist in An Abandoned Fun House', 2006, 1, None, 6, Decimal('0.99'), 73, Decimal('21.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (64, 'BEETHOVEN EXORCIST', 'A Epic Display of a Pioneer And a Student who must Challenge a Butler in The Gulf of Mexico', 2006, 1, None, 6, Decimal('0.99'), 151, Decimal('26.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (65, 'BEHAVIOR RUNAWAY', 'A Unbelieveable Drama of a Student And a Husband who must Outrace a Sumo Wrestler in Berlin', 2006, 1, None, 3, Decimal('4.99'), 100, Decimal('20.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (68, 'BETRAYED REAR', 'A Emotional Character Study of a Boat And a Pioneer who must Find a Explorer in A Shark Tank', 2006, 1, None, 5, Decimal('4.99'), 122, Decimal('26.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (71, 'BILKO ANONYMOUS', 'A Emotional Reflection of a Teacher And a Man who must Meet a Cat in The First Manned Space Station', 2006, 1, None, 3, Decimal('4.99'), 100, Decimal('25.99'), 'PG-13', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (75, 'BIRD INDEPENDENCE', 'A Thrilling Documentary of a Car And a Student who must Sink a Hunter in The Canadian Rockies', 2006, 1, None, 6, Decimal('4.99'), 163, Decimal('14.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (76, 'BIRDCAGE CASPER', 'A Fast-Paced Saga of a Frisbee And a Astronaut who must Overcome a Feminist in Ancient India', 2006, 1, None, 4, Decimal('0.99'), 103, Decimal('23.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (77, 'BIRDS PERDITION', 'A Boring Story of a Womanizer And a Pioneer who must Face a Dog in California', 2006, 1, None, 5, Decimal('4.99'), 61, Decimal('15.99'), 'G', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (79, 'BLADE POLISH', 'A Thoughtful Character Study of a Frisbee And a Pastry Chef who must Fight a Dentist in The First Manned Space Station', 2006, 1, None, 5, Decimal('0.99'), 114, Decimal('10.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (81, 'BLINDNESS GUN', 'A Touching Drama of a Robot And a Dentist who must Meet a Hunter in A Jet Boat', 2006, 1, None, 6, Decimal('4.99'), 103, Decimal('29.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (82, 'BLOOD ARGONAUTS', 'A Boring Drama of a Explorer And a Man who must Kill a Lumberjack in A Manhattan Penthouse', 2006, 1, None, 3, Decimal('0.99'), 71, Decimal('13.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (83, 'BLUES INSTINCT', 'A Insightful Documentary of a Boat And a Composer who must Meet a Forensic Psychologist in An Abandoned Fun House', 2006, 1, None, 5, Decimal('2.99'), 50, Decimal('18.99'), 'G', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (86, 'BOOGIE AMELIE', 'A Lacklusture Character Study of a Husband And a Sumo Wrestler who must Succumb a Technical Writer in The Gulf of Mexico', 2006, 1, None, 6, Decimal('4.99'), 121, Decimal('11.99'), 'R', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (87, 'BOONDOCK BALLROOM', 'A Fateful Panorama of a Crocodile And a Boy who must Defeat a Monkey in The Gulf of Mexico', 2006, 1, None, 7, Decimal('0.99'), 76, Decimal('14.99'), 'NC-17', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (89, 'BORROWERS BEDAZZLED', 'A Brilliant Epistle of a Teacher And a Sumo Wrestler who must Defeat a Man in An Abandoned Fun House', 2006, 1, None, 7, Decimal('0.99'), 63, Decimal('22.99'), 'G', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (91, 'BOUND CHEAPER', 'A Thrilling Panorama of a Database Administrator And a Astronaut who must Challenge a Lumberjack in A Baloon', 2006, 1, None, 5, Decimal('0.99'), 98, Decimal('17.99'), 'PG', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (97, 'BRIDE INTRIGUE', 'A Epic Tale of a Robot And a Monkey who must Vanquish a Man in New Orleans', 2006, 1, None, 7, Decimal('0.99'), 56, Decimal('24.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (101, 'BROTHERHOOD BLANKET', 'A Fateful Character Study of a Butler And a Technical Writer who must Sink a Astronaut in Ancient Japan', 2006, 1, None, 3, Decimal('0.99'), 73, Decimal('26.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (102, 'BUBBLE GROSSE', 'A Awe-Inspiring Panorama of a Crocodile And a Moose who must Confront a Girl in A Baloon', 2006, 1, None, 4, Decimal('4.99'), 60, Decimal('20.99'), 'R', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (107, 'BUNCH MINDS', 'A Emotional Story of a Feminist And a Feminist who must Escape a Pastry Chef in A MySQL Convention', 2006, 1, None, 4, Decimal('2.99'), 63, Decimal('13.99'), 'G', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (109, 'BUTTERFLY CHOCOLAT', 'A Fateful Story of a Girl And a Composer who must Conquer a Husband in A Shark Tank', 2006, 1, None, 3, Decimal('0.99'), 89, Decimal('17.99'), 'G', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (112, 'CALENDAR GUNFIGHT', 'A Thrilling Drama of a Frisbee And a Lumberjack who must Sink a Man in Nigeria', 2006, 1, None, 4, Decimal('4.99'), 120, Decimal('22.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (114, 'CAMELOT VACATION', 'A Touching Character Study of a Woman And a Waitress who must Battle a Pastry Chef in A MySQL Convention', 2006, 1, None, 3, Decimal('0.99'), 61, Decimal('26.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (115, 'CAMPUS REMEMBER', 'A Astounding Drama of a Crocodile And a Mad Cow who must Build a Robot in A Jet Boat', 2006, 1, None, 5, Decimal('2.99'), 167, Decimal('27.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (116, 'CANDIDATE PERDITION', 'A Brilliant Epistle of a Composer And a Database Administrator who must Vanquish a Mad Scientist in The First Manned Space Station', 2006, 1, None, 4, Decimal('2.99'), 70, Decimal('10.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (121, 'CAROL TEXAS', 'A Astounding Character Study of a Composer And a Student who must Overcome a Composer in A Monastery', 2006, 1, None, 4, Decimal('2.99'), 151, Decimal('15.99'), 'PG', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (122, 'CARRIE BUNCH', 'A Amazing Epistle of a Student And a Astronaut who must Discover a Frisbee in The Canadian Rockies', 2006, 1, None, 7, Decimal('0.99'), 114, Decimal('11.99'), 'PG', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (123, 'CASABLANCA SUPER', 'A Amazing Panorama of a Crocodile And a Forensic Psychologist who must Pursue a Secret Agent in The First Manned Space Station', 2006, 1, None, 6, Decimal('4.99'), 85, Decimal('22.99'), 'G', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (125, 'CASSIDY WYOMING', 'A Intrepid Drama of a Frisbee And a Hunter who must Kill a Secret Agent in New Orleans', 2006, 1, None, 5, Decimal('2.99'), 61, Decimal('19.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (128, 'CATCH AMISTAD', 'A Boring Reflection of a Lumberjack And a Feminist who must Discover a Woman in Nigeria', 2006, 1, None, 7, Decimal('0.99'), 183, Decimal('10.99'), 'G', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (129, 'CAUSE DATE', 'A Taut Tale of a Explorer And a Pastry Chef who must Conquer a Hunter in A MySQL Convention', 2006, 1, None, 3, Decimal('2.99'), 179, Decimal('16.99'), 'R', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (130, 'CELEBRITY HORN', 'A Amazing Documentary of a Secret Agent And a Astronaut who must Vanquish a Hunter in A Shark Tank', 2006, 1, None, 7, Decimal('0.99'), 110, Decimal('24.99'), 'PG-13', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (132, 'CHAINSAW UPTOWN', 'A Beautiful Documentary of a Boy And a Robot who must Discover a Squirrel in Australia', 2006, 1, None, 6, Decimal('0.99'), 114, Decimal('25.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (135, 'CHANCE RESURRECTION', 'A Astounding Story of a Forensic Psychologist And a Forensic Psychologist who must Overcome a Moose in Ancient China', 2006, 1, None, 3, Decimal('2.99'), 70, Decimal('22.99'), 'R', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (136, 'CHAPLIN LICENSE', 'A Boring Drama of a Dog And a Forensic Psychologist who must Outrace a Explorer in Ancient India', 2006, 1, None, 7, Decimal('2.99'), 146, Decimal('26.99'), 'NC-17', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (137, 'CHARADE DUFFEL', 'A Action-Packed Display of a Man And a Waitress who must Build a Dog in A MySQL Convention', 2006, 1, None, 3, Decimal('2.99'), 66, Decimal('21.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (138, 'CHARIOTS CONSPIRACY', 'A Unbelieveable Epistle of a Robot And a Husband who must Chase a Robot in The First Manned Space Station', 2006, 1, None, 5, Decimal('2.99'), 71, Decimal('29.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (140, 'CHEAPER CLYDE', 'A Emotional Character Study of a Pioneer And a Girl who must Discover a Dog in Ancient Japan', 2006, 1, None, 6, Decimal('0.99'), 87, Decimal('23.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (141, 'CHICAGO NORTH', 'A Fateful Yarn of a Mad Cow And a Waitress who must Battle a Student in California', 2006, 1, None, 6, Decimal('4.99'), 185, Decimal('11.99'), 'PG-13', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (142, 'CHICKEN HELLFIGHTERS', 'A Emotional Drama of a Dog And a Explorer who must Outrace a Technical Writer in Australia', 2006, 1, None, 3, Decimal('0.99'), 122, Decimal('24.99'), 'PG', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (145, 'CHISUM BEHAVIOR', 'A Epic Documentary of a Sumo Wrestler And a Butler who must Kill a Car in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 124, Decimal('25.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (147, 'CHOCOLAT HARRY', 'A Action-Packed Epistle of a Dentist And a Moose who must Meet a Mad Cow in Ancient Japan', 2006, 1, None, 5, Decimal('0.99'), 101, Decimal('16.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (148, 'CHOCOLATE DUCK', 'A Unbelieveable Story of a Mad Scientist And a Technical Writer who must Discover a Composer in Ancient China', 2006, 1, None, 3, Decimal('2.99'), 132, Decimal('13.99'), 'R', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (149, 'CHRISTMAS MOONSHINE', 'A Action-Packed Epistle of a Feminist And a Astronaut who must Conquer a Boat in A Manhattan Penthouse', 2006, 1, None, 7, Decimal('0.99'), 150, Decimal('21.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (150, 'CIDER DESIRE', 'A Stunning Character Study of a Composer And a Mad Cow who must Succumb a Cat in Soviet Georgia', 2006, 1, None, 7, Decimal('2.99'), 101, Decimal('9.99'), 'PG', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (152, 'CIRCUS YOUTH', 'A Thoughtful Drama of a Pastry Chef And a Dentist who must Pursue a Girl in A Baloon', 2006, 1, None, 5, Decimal('2.99'), 90, Decimal('13.99'), 'PG-13', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (155, 'CLEOPATRA DEVIL', 'A Fanciful Documentary of a Crocodile And a Technical Writer who must Fight a A Shark in A Baloon', 2006, 1, None, 6, Decimal('0.99'), 150, Decimal('26.99'), 'PG-13', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (157, 'CLOCKWORK PARADISE', 'A Insightful Documentary of a Technical Writer And a Feminist who must Challenge a Cat in A Baloon', 2006, 1, None, 7, Decimal('0.99'), 143, Decimal('29.99'), 'PG-13', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (158, 'CLONES PINOCCHIO', 'A Amazing Drama of a Car And a Robot who must Pursue a Dentist in New Orleans', 2006, 1, None, 6, Decimal('2.99'), 124, Decimal('16.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (159, 'CLOSER BANG', 'A Unbelieveable Panorama of a Frisbee And a Hunter who must Vanquish a Monkey in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 58, Decimal('12.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (161, 'CLUE GRAIL', 'A Taut Tale of a Butler And a Mad Scientist who must Build a Crocodile in Ancient China', 2006, 1, None, 6, Decimal('4.99'), 70, Decimal('27.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (162, 'CLUELESS BUCKET', 'A Taut Tale of a Car And a Pioneer who must Conquer a Sumo Wrestler in An Abandoned Fun House', 2006, 1, None, 4, Decimal('2.99'), 95, Decimal('13.99'), 'R', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (163, 'CLYDE THEORY', 'A Beautiful Yarn of a Astronaut And a Frisbee who must Overcome a Explorer in A Jet Boat', 2006, 1, None, 4, Decimal('0.99'), 139, Decimal('29.99'), 'PG-13', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (164, 'COAST RAINBOW', 'A Astounding Documentary of a Mad Cow And a Pioneer who must Challenge a Butler in The Sahara Desert', 2006, 1, None, 4, Decimal('0.99'), 55, Decimal('20.99'), 'PG', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (166, 'COLOR PHILADELPHIA', 'A Thoughtful Panorama of a Car And a Crocodile who must Sink a Monkey in The Sahara Desert', 2006, 1, None, 6, Decimal('2.99'), 149, Decimal('19.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (168, 'COMANCHEROS ENEMY', 'A Boring Saga of a Lumberjack And a Monkey who must Find a Monkey in The Gulf of Mexico', 2006, 1, None, 5, Decimal('0.99'), 67, Decimal('23.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (169, 'COMFORTS RUSH', 'A Unbelieveable Panorama of a Pioneer And a Husband who must Meet a Mad Cow in An Abandoned Mine Shaft', 2006, 1, None, 3, Decimal('2.99'), 76, Decimal('19.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (170, 'COMMAND DARLING', 'A Awe-Inspiring Tale of a Forensic Psychologist And a Woman who must Challenge a Database Administrator in Ancient Japan', 2006, 1, None, 5, Decimal('4.99'), 120, Decimal('28.99'), 'PG-13', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (172, 'CONEHEADS SMOOCHY', 'A Touching Story of a Womanizer And a Composer who must Pursue a Husband in Nigeria', 2006, 1, None, 7, Decimal('4.99'), 112, Decimal('12.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (173, 'CONFESSIONS MAGUIRE', 'A Insightful Story of a Car And a Boy who must Battle a Technical Writer in A Baloon', 2006, 1, None, 7, Decimal('4.99'), 65, Decimal('25.99'), 'PG-13', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (175, 'CONFUSED CANDLES', 'A Stunning Epistle of a Cat And a Forensic Psychologist who must Confront a Pioneer in A Baloon', 2006, 1, None, 3, Decimal('2.99'), 122, Decimal('27.99'), 'PG-13', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (176, 'CONGENIALITY QUEST', 'A Touching Documentary of a Cat And a Pastry Chef who must Find a Lumberjack in A Baloon', 2006, 1, None, 6, Decimal('0.99'), 87, Decimal('21.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (178, 'CONNECTION MICROCOSMOS', 'A Fateful Documentary of a Crocodile And a Husband who must Face a Husband in The First Manned Space Station', 2006, 1, None, 6, Decimal('0.99'), 115, Decimal('25.99'), 'G', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (179, 'CONQUERER NUTS', 'A Taut Drama of a Mad Scientist And a Man who must Escape a Pioneer in An Abandoned Mine Shaft', 2006, 1, None, 4, Decimal('4.99'), 173, Decimal('14.99'), 'G', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (185, 'COWBOY DOOM', 'A Astounding Drama of a Boy And a Lumberjack who must Fight a Butler in A Baloon', 2006, 1, None, 3, Decimal('2.99'), 146, Decimal('10.99'), 'PG', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (186, 'CRAFT OUTFIELD', 'A Lacklusture Display of a Explorer And a Hunter who must Succumb a Database Administrator in A Baloon Factory', 2006, 1, None, 6, Decimal('0.99'), 64, Decimal('17.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (190, 'CREEPERS KANE', 'A Awe-Inspiring Reflection of a Squirrel And a Boat who must Outrace a Car in A Jet Boat', 2006, 1, None, 5, Decimal('4.99'), 172, Decimal('23.99'), 'NC-17', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (191, 'CROOKED FROGMEN', 'A Unbelieveable Drama of a Hunter And a Database Administrator who must Battle a Crocodile in An Abandoned Amusement Park', 2006, 1, None, 6, Decimal('0.99'), 143, Decimal('27.99'), 'PG-13', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (192, 'CROSSING DIVORCE', 'A Beautiful Documentary of a Dog And a Robot who must Redeem a Womanizer in Berlin', 2006, 1, None, 4, Decimal('4.99'), 50, Decimal('19.99'), 'R', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (193, 'CROSSROADS CASUALTIES', 'A Intrepid Documentary of a Sumo Wrestler And a Astronaut who must Battle a Composer in The Outback', 2006, 1, None, 5, Decimal('2.99'), 153, Decimal('20.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (194, 'CROW GREASE', 'A Awe-Inspiring Documentary of a Woman And a Husband who must Sink a Database Administrator in The First Manned Space Station', 2006, 1, None, 6, Decimal('0.99'), 104, Decimal('22.99'), 'PG', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (195, 'CROWDS TELEMARK', 'A Intrepid Documentary of a Astronaut And a Forensic Psychologist who must Find a Frisbee in An Abandoned Fun House', 2006, 1, None, 3, Decimal('4.99'), 112, Decimal('16.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (196, 'CRUELTY UNFORGIVEN', 'A Brilliant Tale of a Car And a Moose who must Battle a Dentist in Nigeria', 2006, 1, None, 7, Decimal('0.99'), 69, Decimal('29.99'), 'G', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (199, 'CUPBOARD SINNERS', 'A Emotional Reflection of a Frisbee And a Boat who must Reach a Pastry Chef in An Abandoned Amusement Park', 2006, 1, None, 4, Decimal('2.99'), 56, Decimal('29.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (200, 'CURTAIN VIDEOTAPE', 'A Boring Reflection of a Dentist And a Mad Cow who must Chase a Secret Agent in A Shark Tank', 2006, 1, None, 7, Decimal('0.99'), 133, Decimal('27.99'), 'PG-13', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (202, 'DADDY PITTSBURGH', 'A Epic Story of a A Shark And a Student who must Confront a Explorer in The Gulf of Mexico', 2006, 1, None, 5, Decimal('4.99'), 161, Decimal('26.99'), 'G', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (203, 'DAISY MENAGERIE', 'A Fast-Paced Saga of a Pastry Chef And a Monkey who must Sink a Composer in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 84, Decimal('9.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (205, 'DANCES NONE', 'A Insightful Reflection of a A Shark And a Dog who must Kill a Butler in An Abandoned Amusement Park', 2006, 1, None, 3, Decimal('0.99'), 58, Decimal('22.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (206, 'DANCING FEVER', 'A Stunning Story of a Explorer And a Forensic Psychologist who must Face a Crocodile in A Shark Tank', 2006, 1, None, 6, Decimal('0.99'), 144, Decimal('25.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (208, 'DARES PLUTO', 'A Fateful Story of a Robot And a Dentist who must Defeat a Astronaut in New Orleans', 2006, 1, None, 7, Decimal('2.99'), 89, Decimal('16.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (209, 'DARKNESS WAR', 'A Touching Documentary of a Husband And a Hunter who must Escape a Boy in The Sahara Desert', 2006, 1, None, 6, Decimal('2.99'), 99, Decimal('24.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (210, 'DARKO DORADO', 'A Stunning Reflection of a Frisbee And a Husband who must Redeem a Dog in New Orleans', 2006, 1, None, 3, Decimal('4.99'), 130, Decimal('13.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (211, 'DARLING BREAKING', 'A Brilliant Documentary of a Astronaut And a Squirrel who must Succumb a Student in The Gulf of Mexico', 2006, 1, None, 7, Decimal('4.99'), 165, Decimal('20.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (215, 'DAWN POND', 'A Thoughtful Documentary of a Dentist And a Forensic Psychologist who must Defeat a Waitress in Berlin', 2006, 1, None, 4, Decimal('4.99'), 57, Decimal('27.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (216, 'DAY UNFAITHFUL', 'A Stunning Documentary of a Composer And a Mad Scientist who must Find a Technical Writer in A U-Boat', 2006, 1, None, 3, Decimal('4.99'), 113, Decimal('16.99'), 'G', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (218, 'DECEIVER BETRAYED', 'A Taut Story of a Moose And a Squirrel who must Build a Husband in Ancient India', 2006, 1, None, 7, Decimal('0.99'), 122, Decimal('22.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (219, 'DEEP CRUSADE', 'A Amazing Tale of a Crocodile And a Squirrel who must Discover a Composer in Australia', 2006, 1, None, 6, Decimal('4.99'), 51, Decimal('20.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (222, 'DESERT POSEIDON', 'A Brilliant Documentary of a Butler And a Frisbee who must Build a Astronaut in New Orleans', 2006, 1, None, 4, Decimal('4.99'), 64, Decimal('27.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (225, 'DESTINATION JERK', 'A Beautiful Yarn of a Teacher And a Cat who must Build a Car in A U-Boat', 2006, 1, None, 3, Decimal('0.99'), 76, Decimal('19.99'), 'PG-13', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (226, 'DESTINY SATURDAY', 'A Touching Drama of a Crocodile And a Crocodile who must Conquer a Explorer in Soviet Georgia', 2006, 1, None, 4, Decimal('4.99'), 56, Decimal('20.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (228, 'DETECTIVE VISION', 'A Fanciful Documentary of a Pioneer And a Woman who must Redeem a Hunter in Ancient Japan', 2006, 1, None, 4, Decimal('0.99'), 143, Decimal('16.99'), 'PG-13', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (229, 'DEVIL DESIRE', 'A Beautiful Reflection of a Monkey And a Dentist who must Face a Database Administrator in Ancient Japan', 2006, 1, None, 6, Decimal('4.99'), 87, Decimal('12.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (230, 'DIARY PANIC', 'A Thoughtful Character Study of a Frisbee And a Mad Cow who must Outgun a Man in Ancient India', 2006, 1, None, 7, Decimal('2.99'), 107, Decimal('20.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (231, 'DINOSAUR SECRETARY', 'A Action-Packed Drama of a Feminist And a Girl who must Reach a Robot in The Canadian Rockies', 2006, 1, None, 7, Decimal('2.99'), 63, Decimal('27.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (232, 'DIRTY ACE', 'A Action-Packed Character Study of a Forensic Psychologist And a Girl who must Build a Dentist in The Outback', 2006, 1, None, 7, Decimal('2.99'), 147, Decimal('29.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (233, 'DISCIPLE MOTHER', 'A Touching Reflection of a Mad Scientist And a Boat who must Face a Moose in A Shark Tank', 2006, 1, None, 3, Decimal('0.99'), 141, Decimal('17.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (234, 'DISTURBING SCARFACE', 'A Lacklusture Display of a Crocodile And a Butler who must Overcome a Monkey in A U-Boat', 2006, 1, None, 6, Decimal('2.99'), 94, Decimal('27.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (238, 'DOCTOR GRAIL', 'A Insightful Drama of a Womanizer And a Waitress who must Reach a Forensic Psychologist in The Outback', 2006, 1, None, 4, Decimal('2.99'), 57, Decimal('29.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (241, 'DONNIE ALLEY', 'A Awe-Inspiring Tale of a Butler And a Frisbee who must Vanquish a Teacher in Ancient Japan', 2006, 1, None, 4, Decimal('0.99'), 125, Decimal('20.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (243, 'DOORS PRESIDENT', 'A Awe-Inspiring Display of a Squirrel And a Woman who must Overcome a Boy in The Gulf of Mexico', 2006, 1, None, 3, Decimal('4.99'), 49, Decimal('22.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (245, 'DOUBLE WRATH', 'A Thoughtful Yarn of a Womanizer And a Dog who must Challenge a Madman in The Gulf of Mexico', 2006, 1, None, 4, Decimal('0.99'), 177, Decimal('28.99'), 'R', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (246, 'DOUBTFIRE LABYRINTH', 'A Intrepid Panorama of a Butler And a Composer who must Meet a Mad Cow in The Sahara Desert', 2006, 1, None, 5, Decimal('4.99'), 154, Decimal('16.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (248, 'DOZEN LION', 'A Taut Drama of a Cat And a Girl who must Defeat a Frisbee in The Canadian Rockies', 2006, 1, None, 6, Decimal('4.99'), 177, Decimal('20.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (250, 'DRAGON SQUAD', 'A Taut Reflection of a Boy And a Waitress who must Outgun a Teacher in Ancient China', 2006, 1, None, 4, Decimal('0.99'), 170, Decimal('26.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (251, 'DRAGONFLY STRANGERS', 'A Boring Documentary of a Pioneer And a Man who must Vanquish a Man in Nigeria', 2006, 1, None, 6, Decimal('4.99'), 133, Decimal('19.99'), 'NC-17', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (252, 'DREAM PICKUP', 'A Epic Display of a Car And a Composer who must Overcome a Forensic Psychologist in The Gulf of Mexico', 2006, 1, None, 6, Decimal('2.99'), 135, Decimal('18.99'), 'PG', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (253, 'DRIFTER COMMANDMENTS', 'A Epic Reflection of a Womanizer And a Squirrel who must Discover a Husband in A Jet Boat', 2006, 1, None, 5, Decimal('4.99'), 61, Decimal('18.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (254, 'DRIVER ANNIE', 'A Lacklusture Character Study of a Butler And a Car who must Redeem a Boat in An Abandoned Fun House', 2006, 1, None, 4, Decimal('2.99'), 159, Decimal('11.99'), 'PG-13', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (257, 'DRUMLINE CYCLONE', 'A Insightful Panorama of a Monkey And a Sumo Wrestler who must Outrace a Mad Scientist in The Canadian Rockies', 2006, 1, None, 3, Decimal('0.99'), 110, Decimal('14.99'), 'G', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (259, 'DUCK RACER', 'A Lacklusture Yarn of a Teacher And a Squirrel who must Overcome a Dog in A Shark Tank', 2006, 1, None, 4, Decimal('2.99'), 116, Decimal('15.99'), 'NC-17', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (262, 'DUMBO LUST', 'A Touching Display of a Feminist And a Dentist who must Conquer a Husband in The Gulf of Mexico', 2006, 1, None, 5, Decimal('0.99'), 119, Decimal('17.99'), 'NC-17', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (265, 'DYING MAKER', 'A Intrepid Tale of a Boat And a Monkey who must Kill a Cat in California', 2006, 1, None, 5, Decimal('4.99'), 168, Decimal('28.99'), 'PG', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (267, 'EAGLES PANKY', 'A Thoughtful Story of a Car And a Boy who must Find a A Shark in The Sahara Desert', 2006, 1, None, 4, Decimal('4.99'), 140, Decimal('14.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (268, 'EARLY HOME', 'A Amazing Panorama of a Mad Scientist And a Husband who must Meet a Woman in The Outback', 2006, 1, None, 6, Decimal('4.99'), 96, Decimal('27.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (269, 'EARRING INSTINCT', 'A Stunning Character Study of a Dentist And a Mad Cow who must Find a Teacher in Nigeria', 2006, 1, None, 3, Decimal('0.99'), 98, Decimal('22.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (271, 'EASY GLADIATOR', 'A Fateful Story of a Monkey And a Girl who must Overcome a Pastry Chef in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 148, Decimal('12.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (274, 'EGG IGBY', 'A Beautiful Documentary of a Boat And a Sumo Wrestler who must Succumb a Database Administrator in The First Manned Space Station', 2006, 1, None, 4, Decimal('2.99'), 67, Decimal('20.99'), 'PG', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (275, 'EGYPT TENENBAUMS', 'A Intrepid Story of a Madman And a Secret Agent who must Outrace a Astronaut in An Abandoned Amusement Park', 2006, 1, None, 3, Decimal('0.99'), 85, Decimal('11.99'), 'PG', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (276, 'ELEMENT FREDDY', 'A Awe-Inspiring Reflection of a Waitress And a Squirrel who must Kill a Mad Cow in A Jet Boat', 2006, 1, None, 6, Decimal('4.99'), 115, Decimal('28.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (277, 'ELEPHANT TROJAN', 'A Beautiful Panorama of a Lumberjack And a Forensic Psychologist who must Overcome a Frisbee in A Baloon', 2006, 1, None, 4, Decimal('4.99'), 126, Decimal('24.99'), 'PG-13', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (278, 'ELF MURDER', 'A Action-Packed Story of a Frisbee And a Woman who must Reach a Girl in An Abandoned Mine Shaft', 2006, 1, None, 4, Decimal('4.99'), 155, Decimal('19.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (279, 'ELIZABETH SHANE', 'A Lacklusture Display of a Womanizer And a Dog who must Face a Sumo Wrestler in Ancient Japan', 2006, 1, None, 7, Decimal('4.99'), 152, Decimal('11.99'), 'NC-17', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (281, 'ENCINO ELF', 'A Astounding Drama of a Feminist And a Teacher who must Confront a Husband in A Baloon', 2006, 1, None, 6, Decimal('0.99'), 143, Decimal('9.99'), 'G', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (283, 'ENDING CROWDS', 'A Unbelieveable Display of a Dentist And a Madman who must Vanquish a Squirrel in Berlin', 2006, 1, None, 6, Decimal('0.99'), 85, Decimal('10.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (287, 'ENTRAPMENT SATISFACTION', 'A Thoughtful Panorama of a Hunter And a Teacher who must Reach a Mad Cow in A U-Boat', 2006, 1, None, 5, Decimal('0.99'), 176, Decimal('19.99'), 'R', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (291, 'EVOLUTION ALTER', 'A Fanciful Character Study of a Feminist And a Madman who must Find a Explorer in A Baloon Factory', 2006, 1, None, 5, Decimal('0.99'), 174, Decimal('10.99'), 'PG-13', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (293, 'EXORCIST STING', 'A Touching Drama of a Dog And a Sumo Wrestler who must Conquer a Mad Scientist in Berlin', 2006, 1, None, 6, Decimal('2.99'), 167, Decimal('17.99'), 'G', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (295, 'EXPENDABLE STALLION', 'A Amazing Character Study of a Mad Cow And a Squirrel who must Discover a Hunter in A U-Boat', 2006, 1, None, 3, Decimal('0.99'), 97, Decimal('14.99'), 'PG', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (300, 'FALCON VOLUME', 'A Fateful Saga of a Sumo Wrestler And a Hunter who must Redeem a A Shark in New Orleans', 2006, 1, None, 5, Decimal('4.99'), 102, Decimal('21.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (303, 'FANTASY TROOPERS', 'A Touching Saga of a Teacher And a Monkey who must Overcome a Secret Agent in A MySQL Convention', 2006, 1, None, 6, Decimal('0.99'), 58, Decimal('27.99'), 'PG-13', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (305, 'FATAL HAUNTED', 'A Beautiful Drama of a Student And a Secret Agent who must Confront a Dentist in Ancient Japan', 2006, 1, None, 6, Decimal('2.99'), 91, Decimal('24.99'), 'PG', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (307, 'FELLOWSHIP AUTUMN', 'A Lacklusture Reflection of a Dentist And a Hunter who must Meet a Teacher in A Baloon', 2006, 1, None, 6, Decimal('4.99'), 77, Decimal('9.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (308, 'FERRIS MOTHER', 'A Touching Display of a Frisbee And a Frisbee who must Kill a Girl in The Gulf of Mexico', 2006, 1, None, 3, Decimal('2.99'), 142, Decimal('13.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (309, 'FEUD FROGMEN', 'A Brilliant Reflection of a Database Administrator And a Mad Cow who must Chase a Woman in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 98, Decimal('29.99'), 'R', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (311, 'FICTION CHRISTMAS', 'A Emotional Yarn of a A Shark And a Student who must Battle a Robot in An Abandoned Mine Shaft', 2006, 1, None, 4, Decimal('0.99'), 72, Decimal('14.99'), 'PG', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (312, 'FIDDLER LOST', 'A Boring Tale of a Squirrel And a Dog who must Challenge a Madman in The Gulf of Mexico', 2006, 1, None, 4, Decimal('4.99'), 75, Decimal('20.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (313, 'FIDELITY DEVIL', 'A Awe-Inspiring Drama of a Technical Writer And a Composer who must Reach a Pastry Chef in A U-Boat', 2006, 1, None, 5, Decimal('4.99'), 118, Decimal('11.99'), 'G', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (314, 'FIGHT JAWBREAKER', 'A Intrepid Panorama of a Womanizer And a Girl who must Escape a Girl in A Manhattan Penthouse', 2006, 1, None, 3, Decimal('0.99'), 91, Decimal('13.99'), 'R', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (317, 'FIREBALL PHILADELPHIA', 'A Amazing Yarn of a Dentist And a A Shark who must Vanquish a Madman in An Abandoned Mine Shaft', 2006, 1, None, 4, Decimal('0.99'), 148, Decimal('25.99'), 'PG', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (319, 'FISH OPUS', 'A Touching Display of a Feminist And a Girl who must Confront a Astronaut in Australia', 2006, 1, None, 4, Decimal('2.99'), 125, Decimal('22.99'), 'R', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (321, 'FLASH WARS', 'A Astounding Saga of a Moose And a Pastry Chef who must Chase a Student in The Gulf of Mexico', 2006, 1, None, 3, Decimal('4.99'), 123, Decimal('21.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (324, 'FLINTSTONES HAPPINESS', 'A Fateful Story of a Husband And a Moose who must Vanquish a Boy in California', 2006, 1, None, 3, Decimal('4.99'), 148, Decimal('11.99'), 'PG-13', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (325, 'FLOATS GARDEN', 'A Action-Packed Epistle of a Robot And a Car who must Chase a Boat in Ancient Japan', 2006, 1, None, 6, Decimal('2.99'), 145, Decimal('29.99'), 'PG-13', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (326, 'FLYING HOOK', 'A Thrilling Display of a Mad Cow And a Dog who must Challenge a Frisbee in Nigeria', 2006, 1, None, 6, Decimal('2.99'), 69, Decimal('18.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (328, 'FOREVER CANDIDATE', 'A Unbelieveable Panorama of a Technical Writer And a Man who must Pursue a Frisbee in A U-Boat', 2006, 1, None, 7, Decimal('2.99'), 131, Decimal('28.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# ...
# (896, 'TOOTSIE PILOT', 'A Awe-Inspiring Documentary of a Womanizer And a Pastry Chef who must Kill a Lumberjack in Berlin', 2006, 1, None, 3, Decimal('0.99'), 157, Decimal('10.99'), 'PG', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (899, 'TOWERS HURRICANE', 'A Fateful Display of a Monkey And a Car who must Sink a Husband in A MySQL Convention', 2006, 1, None, 7, Decimal('0.99'), 144, Decimal('14.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (900, 'TOWN ARK', 'A Awe-Inspiring Documentary of a Moose And a Madman who must Meet a Dog in An Abandoned Mine Shaft', 2006, 1, None, 6, Decimal('2.99'), 136, Decimal('17.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (901, 'TRACY CIDER', 'A Touching Reflection of a Database Administrator And a Madman who must Build a Lumberjack in Nigeria', 2006, 1, None, 3, Decimal('0.99'), 142, Decimal('29.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (902, 'TRADING PINOCCHIO', 'A Emotional Character Study of a Student And a Explorer who must Discover a Frisbee in The First Manned Space Station', 2006, 1, None, 6, Decimal('4.99'), 170, Decimal('22.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (908, 'TRAP GUYS', 'A Unbelieveable Story of a Boy And a Mad Cow who must Challenge a Database Administrator in The Sahara Desert', 2006, 1, None, 3, Decimal('4.99'), 110, Decimal('11.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (909, 'TREASURE COMMAND', 'A Emotional Saga of a Car And a Madman who must Discover a Pioneer in California', 2006, 1, None, 3, Decimal('0.99'), 102, Decimal('28.99'), 'PG-13', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (910, 'TREATMENT JEKYLL', 'A Boring Story of a Teacher And a Student who must Outgun a Cat in An Abandoned Mine Shaft', 2006, 1, None, 3, Decimal('0.99'), 87, Decimal('19.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (913, 'TROOPERS METAL', 'A Fanciful Drama of a Monkey And a Feminist who must Sink a Man in Berlin', 2006, 1, None, 3, Decimal('0.99'), 115, Decimal('20.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (914, 'TROUBLE DATE', 'A Lacklusture Panorama of a Forensic Psychologist And a Woman who must Kill a Explorer in Ancient Japan', 2006, 1, None, 6, Decimal('2.99'), 61, Decimal('13.99'), 'PG', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (916, 'TURN STAR', 'A Stunning Tale of a Man And a Monkey who must Chase a Student in New Orleans', 2006, 1, None, 3, Decimal('2.99'), 80, Decimal('10.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (917, 'TUXEDO MILE', 'A Boring Drama of a Man And a Forensic Psychologist who must Face a Frisbee in Ancient India', 2006, 1, None, 3, Decimal('2.99'), 152, Decimal('24.99'), 'R', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (920, 'UNBREAKABLE KARATE', 'A Amazing Character Study of a Robot And a Student who must Chase a Robot in Australia', 2006, 1, None, 3, Decimal('0.99'), 62, Decimal('16.99'), 'G', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (921, 'UNCUT SUICIDES', 'A Intrepid Yarn of a Explorer And a Pastry Chef who must Pursue a Mad Cow in A U-Boat', 2006, 1, None, 7, Decimal('2.99'), 172, Decimal('29.99'), 'PG-13', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (924, 'UNFORGIVEN ZOOLANDER', 'A Taut Epistle of a Monkey And a Sumo Wrestler who must Vanquish a A Shark in A Baloon Factory', 2006, 1, None, 7, Decimal('0.99'), 129, Decimal('15.99'), 'PG', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (927, 'UPRISING UPTOWN', 'A Fanciful Reflection of a Boy And a Butler who must Pursue a Woman in Berlin', 2006, 1, None, 6, Decimal('2.99'), 174, Decimal('16.99'), 'NC-17', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (929, 'USUAL UNTOUCHABLES', 'A Touching Display of a Explorer And a Lumberjack who must Fight a Forensic Psychologist in A Shark Tank', 2006, 1, None, 5, Decimal('4.99'), 128, Decimal('21.99'), 'PG-13', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (931, 'VALENTINE VANISHING', 'A Thrilling Display of a Husband And a Butler who must Reach a Pastry Chef in California', 2006, 1, None, 7, Decimal('0.99'), 48, Decimal('9.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (934, 'VANILLA DAY', 'A Fast-Paced Saga of a Girl And a Forensic Psychologist who must Redeem a Girl in Nigeria', 2006, 1, None, 7, Decimal('4.99'), 122, Decimal('20.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (936, 'VANISHING ROCKY', 'A Brilliant Reflection of a Man And a Woman who must Conquer a Pioneer in A MySQL Convention', 2006, 1, None, 3, Decimal('2.99'), 123, Decimal('21.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (938, 'VELVET TERMINATOR', 'A Lacklusture Tale of a Pastry Chef And a Technical Writer who must Confront a Crocodile in An Abandoned Amusement Park', 2006, 1, None, 3, Decimal('4.99'), 173, Decimal('14.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (939, 'VERTIGO NORTHWEST', 'A Unbelieveable Display of a Mad Scientist And a Mad Scientist who must Outgun a Mad Cow in Ancient Japan', 2006, 1, None, 4, Decimal('2.99'), 90, Decimal('17.99'), 'R', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (940, 'VICTORY ACADEMY', 'A Insightful Epistle of a Mad Scientist And a Explorer who must Challenge a Cat in The Sahara Desert', 2006, 1, None, 6, Decimal('0.99'), 64, Decimal('19.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (941, 'VIDEOTAPE ARSENIC', 'A Lacklusture Display of a Girl And a Astronaut who must Succumb a Student in Australia', 2006, 1, None, 4, Decimal('4.99'), 145, Decimal('10.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (942, 'VIETNAM SMOOCHY', 'A Lacklusture Display of a Butler And a Man who must Sink a Explorer in Soviet Georgia', 2006, 1, None, 7, Decimal('0.99'), 174, Decimal('27.99'), 'PG-13', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (944, 'VIRGIN DAISY', 'A Awe-Inspiring Documentary of a Robot And a Mad Scientist who must Reach a Database Administrator in A Shark Tank', 2006, 1, None, 6, Decimal('4.99'), 179, Decimal('29.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (948, 'VOICE PEACH', 'A Amazing Panorama of a Pioneer And a Student who must Overcome a Mad Scientist in A Manhattan Penthouse', 2006, 1, None, 6, Decimal('0.99'), 139, Decimal('22.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (949, 'VOLCANO TEXAS', 'A Awe-Inspiring Yarn of a Hunter And a Feminist who must Challenge a Dentist in The Outback', 2006, 1, None, 6, Decimal('0.99'), 157, Decimal('27.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (951, 'VOYAGE LEGALLY', 'A Epic Tale of a Squirrel And a Hunter who must Conquer a Boy in An Abandoned Mine Shaft', 2006, 1, None, 6, Decimal('0.99'), 78, Decimal('28.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (952, 'WAGON JAWS', 'A Intrepid Drama of a Moose And a Boat who must Kill a Explorer in A Manhattan Penthouse', 2006, 1, None, 7, Decimal('2.99'), 152, Decimal('17.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (954, 'WAKE JAWS', 'A Beautiful Saga of a Feminist And a Composer who must Challenge a Moose in Berlin', 2006, 1, None, 7, Decimal('4.99'), 73, Decimal('18.99'), 'G', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (955, 'WALLS ARTIST', 'A Insightful Panorama of a Teacher And a Teacher who must Overcome a Mad Cow in An Abandoned Fun House', 2006, 1, None, 7, Decimal('4.99'), 135, Decimal('19.99'), 'PG', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (956, 'WANDA CHAMBER', 'A Insightful Drama of a A Shark And a Pioneer who must Find a Womanizer in The Outback', 2006, 1, None, 7, Decimal('4.99'), 107, Decimal('23.99'), 'PG-13', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (957, 'WAR NOTTING', 'A Boring Drama of a Teacher And a Sumo Wrestler who must Challenge a Secret Agent in The Canadian Rockies', 2006, 1, None, 7, Decimal('4.99'), 80, Decimal('26.99'), 'G', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (959, 'WARLOCK WEREWOLF', 'A Astounding Yarn of a Pioneer And a Crocodile who must Defeat a A Shark in The Outback', 2006, 1, None, 6, Decimal('2.99'), 83, Decimal('10.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (960, 'WARS PLUTO', 'A Taut Reflection of a Teacher And a Database Administrator who must Chase a Madman in The Sahara Desert', 2006, 1, None, 5, Decimal('2.99'), 128, Decimal('15.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (962, 'WASTELAND DIVINE', 'A Fanciful Story of a Database Administrator And a Womanizer who must Fight a Database Administrator in Ancient China', 2006, 1, None, 7, Decimal('2.99'), 85, Decimal('18.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (963, 'WATCH TRACY', 'A Fast-Paced Yarn of a Dog And a Frisbee who must Conquer a Hunter in Nigeria', 2006, 1, None, 5, Decimal('0.99'), 78, Decimal('12.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (964, 'WATERFRONT DELIVERANCE', 'A Unbelieveable Documentary of a Dentist And a Technical Writer who must Build a Womanizer in Nigeria', 2006, 1, None, 4, Decimal('4.99'), 61, Decimal('17.99'), 'G', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (967, 'WEEKEND PERSONAL', 'A Fast-Paced Documentary of a Car And a Butler who must Find a Frisbee in A Jet Boat', 2006, 1, None, 5, Decimal('2.99'), 134, Decimal('26.99'), 'R', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (968, 'WEREWOLF LOLA', 'A Fanciful Story of a Man And a Sumo Wrestler who must Outrace a Student in A Monastery', 2006, 1, None, 6, Decimal('4.99'), 79, Decimal('19.99'), 'G', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (971, 'WHALE BIKINI', 'A Intrepid Story of a Pastry Chef And a Database Administrator who must Kill a Feminist in A MySQL Convention', 2006, 1, None, 4, Decimal('4.99'), 109, Decimal('11.99'), 'PG-13', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (973, 'WIFE TURN', 'A Awe-Inspiring Epistle of a Teacher And a Feminist who must Confront a Pioneer in Ancient Japan', 2006, 1, None, 3, Decimal('4.99'), 183, Decimal('27.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (974, 'WILD APOLLO', 'A Beautiful Story of a Monkey And a Sumo Wrestler who must Conquer a A Shark in A MySQL Convention', 2006, 1, None, 4, Decimal('0.99'), 181, Decimal('24.99'), 'R', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (975, 'WILLOW TRACY', 'A Brilliant Panorama of a Boat And a Astronaut who must Challenge a Teacher in A Manhattan Penthouse', 2006, 1, None, 6, Decimal('2.99'), 137, Decimal('22.99'), 'R', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (977, 'WINDOW SIDE', 'A Astounding Character Study of a Womanizer And a Hunter who must Escape a Robot in A Monastery', 2006, 1, None, 3, Decimal('2.99'), 85, Decimal('25.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (978, 'WISDOM WORKER', 'A Unbelieveable Saga of a Forensic Psychologist And a Student who must Face a Squirrel in The First Manned Space Station', 2006, 1, None, 3, Decimal('0.99'), 98, Decimal('12.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (979, 'WITCHES PANIC', 'A Awe-Inspiring Drama of a Secret Agent And a Hunter who must Fight a Moose in Nigeria', 2006, 1, None, 6, Decimal('4.99'), 100, Decimal('10.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (980, 'WIZARD COLDBLOODED', 'A Lacklusture Display of a Robot And a Girl who must Defeat a Sumo Wrestler in A MySQL Convention', 2006, 1, None, 4, Decimal('4.99'), 75, Decimal('12.99'), 'PG', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (981, 'WOLVES DESIRE', 'A Fast-Paced Drama of a Squirrel And a Robot who must Succumb a Technical Writer in A Manhattan Penthouse', 2006, 1, None, 7, Decimal('0.99'), 55, Decimal('13.99'), 'NC-17', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (982, 'WOMEN DORADO', 'A Insightful Documentary of a Waitress And a Butler who must Vanquish a Composer in Australia', 2006, 1, None, 4, Decimal('0.99'), 126, Decimal('23.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (983, 'WON DARES', 'A Unbelieveable Documentary of a Teacher And a Monkey who must Defeat a Explorer in A U-Boat', 2006, 1, None, 7, Decimal('2.99'), 105, Decimal('18.99'), 'PG', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (988, 'WORKER TARZAN', 'A Action-Packed Yarn of a Secret Agent And a Technical Writer who must Battle a Sumo Wrestler in The First Manned Space Station', 2006, 1, None, 7, Decimal('2.99'), 139, Decimal('26.99'), 'R', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (990, 'WORLD LEATHERNECKS', 'A Unbelieveable Tale of a Pioneer And a Astronaut who must Overcome a Robot in An Abandoned Amusement Park', 2006, 1, None, 3, Decimal('0.99'), 171, Decimal('13.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (991, 'WORST BANGER', 'A Thrilling Drama of a Madman And a Dentist who must Conquer a Boy in The Outback', 2006, 1, None, 4, Decimal('2.99'), 185, Decimal('26.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (993, 'WRONG BEHAVIOR', 'A Emotional Saga of a Crocodile And a Sumo Wrestler who must Discover a Mad Cow in New Orleans', 2006, 1, None, 6, Decimal('2.99'), 178, Decimal('10.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (996, 'YOUNG LANGUAGE', 'A Unbelieveable Yarn of a Boat And a Database Administrator who must Meet a Boy in The First Manned Space Station', 2006, 1, None, 6, Decimal('0.99'), 183, Decimal('9.99'), 'G', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (997, 'YOUTH KICK', 'A Touching Drama of a Teacher And a Cat who must Challenge a Technical Writer in A U-Boat', 2006, 1, None, 4, Decimal('0.99'), 179, Decimal('14.99'), 'NC-17', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (1000, 'ZORRO ARK', 'A Intrepid Panorama of a Mad Scientist And a Boy who must Redeem a Boy in A Monastery', 2006, 1, None, 3, Decimal('4.99'), 50, Decimal('18.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))

# %%
data5=pd.DataFrame(rows)
data5.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        4  AFFAIR PREJUDICE
# 2       11   ALAMO VIDEOTAPE
# 3       13       ALI FOREVER
# 4       14    ALICE FANTASIA
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 2  A Boring Epistle of a Butler And a Cat who mus...          2006
# 3  A Action-Packed Drama of a Dentist And a Croco...          2006
# 4  A Emotional Drama of a A Shark And a Database ...          2006
#
#    language_id original_language_id  rental_duration rental_rate  length  \
# 0            1                 None                6        0.99      86
# 1            1                 None                5        2.99     117
# 2            1                 None                6        0.99     126
# 3            1                 None                4        4.99     150
# 4            1                 None                6        0.99      94
#
#   replacement_cost rating                           special_features  \
# 0            20.99     PG           Deleted Scenes,Behind the Scenes
# 1            26.99      G             Commentaries,Behind the Scenes
# 2            16.99      G             Commentaries,Behind the Scenes
# 3            21.99     PG           Deleted Scenes,Behind the Scenes
# 4            23.99  NC-17  Trailers,Deleted Scenes,Behind the Scenes
#
#           last_update
# 0 2006-02-15 05:03:42
# 1 2006-02-15 05:03:42
# 2 2006-02-15 05:03:42
# 3 2006-02-15 05:03:42
# 4 2006-02-15 05:03:42

# %% [markdown]
# #### 6. Which kind of movies (rating) have a mean duration of more than two hours?

# %%
data6 = pd.read_sql_query(''' SELECT rating, round(AVG(length),2) > 120 FROM sakila.film
GROUP BY rating; ''', engine)
data6.head()
# Out:
#   rating  round(AVG(length),2) > 120
# 0     PG                           0
# 1      G                           0
# 2  NC-17                           0
# 3  PG-13                           1
# 4      R                           0

# %% [markdown]
# #### 7.  Rank films by length (filter out the rows that have nulls or 0s in length column). In your output, only select the columns title, length, and the rank.

# %%
data7 = pd.read_sql_query(''' SELECT 
RANK() OVER(ORDER BY sakila.film.length DESC) AS 'Rank'
    ,sakila.film.title
    , sakila.film.length
FROM
    sakila.film
WHERE
length is not null
AND
length > 0
ORDER BY
length desc; ''', engine)
data7.head()
# Out:
#    Rank           title  length
# 0     1   CHICAGO NORTH     185
# 1     1  CONTROL ANTHEM     185
# 2     1  DARN FORRESTER     185
# 3     1     GANGS PRIDE     185
# 4     1       HOME PITY     185
